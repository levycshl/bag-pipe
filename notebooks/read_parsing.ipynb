# %%
# 🧙 Notebook magic: autoreload modules
# %load_ext autoreload
# %autoreload 2
import bagpipe_io as bpio
import bagpipe_config as bconfig
from pathlib import Path
from read_breaker_io import FastqReader, FastqWriter
from read_breaker_parser import ReadParser
from read_breaker_parser import read_clip_and_write
import yaml

## # — Set up I/O paths & parser (you’ll already have this) —

## provides configuration for the pipeline
## and list of input files
bagpipe_yaml = "../configs/bagpipe_config.yaml"
bagpipe_config = bconfig.load_config(bagpipe_yaml)
## create output directory
out_dir = Path(bagpipe_config["output_dir"])
out_dir.mkdir(exist_ok=True)

## configuration for parsing the reads
read_breaker_config_path = "../configs/bagpipe_2N.yaml"
with open(read_breaker_config_path, "r") as f:
    read_breaker_config = yaml.safe_load(f)

## instantiate the parser
read_parser = ReadParser(
        pipeline_cfg={"pipeline": read_breaker_config["pipeline"]},
        globals_cfg=read_breaker_config["params"],
        globals_namespace="params",
        base_dir = "../"
    )

print(read_parser)

## show how this works for one sample
sample = bagpipe_config["samples"][0]
r1_path = sample["fastq_r1"]
r2_path = sample["fastq_r2"]

stub    = sample["id"]  ## for output file names

## create reader from the input files and a writer for the output
reader = FastqReader(r1_path, r2_path, trim_tail=True)
writer = FastqWriter(str(out_dir), stub)

## read the input files, parse the reads, clip and write the output
read_clip_and_write(
    reader,
    read_parser,
    writer,
    default_start_r1=read_parser.globals.get("start_r1", 0),
    default_start_r2=read_parser.globals.get("start_r2", 0)
)

writer.close()
print("Finished writing output files.")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Loaded 95 barcodes for bc1
# Loaded 96 barcodes for bc2
# Loaded 96 barcodes for bc3
# ReadParser Pipeline:
# [  0 ]  check_upstream_motif_r1: hamming_test (read 1, must pass: True)
# [  1 ]  extract_bc3: extract (read 1, must pass: False)
# [  2 ]  extract_bc2: extract (read 1, must pass: False)
# [  3 ]  extract_bc1: extract (read 1, must pass: False)
# [  4 ]  good_barcodes: test ({{ bc1_match and bc2_match and bc3_match }}, must pass: True)
# [  5 ]  extract_vt3: extract (read 1, must pass: True)
# [  6 ]  extract_vt2: extract (read 1, must pass: True)
# [  7 ]  extract_vt1: extract (read 1, must pass: True)
# [  8 ]  find_adapter_r1: regex_search (read 1, must pass: False)
# [  9 ]  find_polya_r1: regex_search (read 1, must pass: False)
# [ 10 ]  find_adapter_r2: regex_search (read 2, must pass: False)
# [ 11 ]  compute_end_r1: compute ({{ (adapter1_start - params.trim_offset_r1) if adapter1_start is not none else (polya_start if polya_start is not none else len_seq1) }}, must pass: True)
# [ 12 ]  compute_end_r2: compute ({{ (adapter2_start - params.trim_offset_r2) if adapter2_start is not none else len_seq2 }}, must pass: True)
# [ 13 ]  check_read_lens: test ({{(end_r1 >= params.min_read_length_r1 and end_r2 >= params.min_read_length_r2)}}, must pass: True)
# [ 14 ]  assemble_bead_tag: compute ({{ bc3 ~ bc2 ~ bc1 }}, must pass: True)
# [ 15 ]  assemble_varietal_tag: compute ({{ vt3 ~ vt2 ~ vt1 }}, must pass: True)
# [ 16 ]  assemble_read_tag: compute ({{ bead_tag ~ '_' ~ varietal_tag }}, must pass: True)
# Finished writing output files.

# %%
## compare the results of the two output files
r1_path = out_dir / f"{stub}.R1.fastq.gz"
r2_path = out_dir / f"{stub}.R2.fastq.gz"

## original trimmed output files
r1_orig_path = out_dir / f"r1.fastq.gz"
r2_orig_path = out_dir / f"r2.fastq.gz"

new_reader = FastqReader(r1_path, r2_path)
original_reader = FastqReader(r1_orig_path, r2_orig_path)

original_reads = {}
new_reads = {}

for ind, read_pair in enumerate( original_reader ):
    original_reads[read_pair[0]] = read_pair

for ind, read_pair in enumerate( new_reader ):
    new_reads[read_pair[0]] = read_pair

# %%
## compare the dictionaries:
print("Original reads:", len(original_reads))
print("New reads:", len(new_reads))

## turn them into dataframes
import pandas as pd
df_orig = pd.DataFrame.from_dict(original_reads, orient="index")
df_new = pd.DataFrame.from_dict(new_reads, orient="index")
# Out:
# Original reads: 132
# New reads: 132

# %%
import pandas as pd

# (assuming df_orig and df_new already exist and use read-ID as their index)

# 1) give readable column names instead of 0..4
cols = ["id", "seq1", "qual1", "seq2", "qual2"]
df_orig.columns = cols
df_new .columns = cols

# 2) outer-join (union of indices); add suffixes so columns stay separate
cmp = df_orig.join(df_new, how="outer", lsuffix="_orig", rsuffix="_new")

# 3) rows present only on one side
only_orig = cmp[cmp["id_new"].isna()]
only_new  = cmp[cmp["id_orig"].isna()]

print("Missing from NEW:", len(only_orig))
print("Missing from ORIG:", len(only_new))

# 4) for shared rows, flag which columns differ
shared = cmp.dropna(subset=["id_orig", "id_new"])
diff_mask = (shared[[c+"_orig" for c in cols]].values !=
             shared[[c+"_new"  for c in cols]].values)

rows_with_diffs = shared[diff_mask.any(axis=1)]

print("Rows with content differences:", len(rows_with_diffs))

# (optional) inspect a few mismatches
print(rows_with_diffs.head())
# Out:
# Missing from NEW: 0
# Missing from ORIG: 0
# Rows with content differences: 0
# Empty DataFrame
# Columns: [id_orig, seq1_orig, qual1_orig, seq2_orig, qual2_orig, id_new, seq1_new, qual1_new, seq2_new, qual2_new]
# Index: []

# %%
## check the output
#open the output file with a fastq reader
from read_breaker_io import FastqReader

r1_path = out_dir / f"{stub}.R1.fastq.gz"
r2_path = out_dir / f"{stub}.R2.fastq.gz"
reader = FastqReader(r1_path, r2_path)
for ind, read_pair in enumerate( reader):
    print(ind, read_pair[0], [len(x) for x in read_pair[1:]])
# Out:
# 0 A00296:241:HMWTTDRXX:1:1101:17201:6073 1:N:0:CGTACTAG/1_CTGTTAGTTCCCACTTC_ACTTCGCTAGGC [70, 70, 150, 150]
# 1 A00296:241:HMWTTDRXX:1:1101:17219:6073 1:N:0:CGTACTAG/1_CTAAGAATTTACCGTGA_GTTTTAGGGCAG [70, 70, 46, 46]
# 2 A00296:241:HMWTTDRXX:1:1101:17255:6073 1:N:0:CGTACTAG/1_TCTGGAATACCGTGTAA_AAGTACCTCGCG [70, 70, 150, 150]
# 3 A00296:241:HMWTTDRXX:1:1101:17291:6073 1:N:0:CGTACTAG/1_GCTACTGAAGCGGGTCA_CGGGTTATTGAA [70, 70, 42, 42]
# 4 A00296:241:HMWTTDRXX:1:1101:17327:6073 1:N:0:CGTACTAG/1_TGATGGATTCAGATTCC_TGTACAATGCAC [70, 70, 150, 150]
# 5 A00296:241:HMWTTDRXX:1:1101:17345:6073 1:N:0:CGTACTAG/1_GATTTGTAGGAAATACG_TTCAAGTTGGCC [70, 70, 41, 41]
# 6 A00296:241:HMWTTDRXX:1:1101:17363:6073 1:N:0:CGTACTAG/1_GCTTCATAGGAAAGAAG_CGATACATCCGC [70, 70, 150, 150]
# 7 A00296:241:HMWTTDRXX:1:1101:17418:6073 1:N:0:CGTACTAG/1_CATTTAAGTTTGGCTAA_GGGTGCATGTAC [70, 70, 119, 119]
# 8 A00296:241:HMWTTDRXX:1:1101:17616:6073 1:N:0:CGTACTAG/1_TTCACGGAACAATTACC_CAGGATTTAAGA [70, 70, 76, 76]
# 9 A00296:241:HMWTTDRXX:1:1101:17653:6073 1:N:0:CGTACTAG/1_GTTTGGAATTTCCTAAG_AAAACTATACGA [70, 70, 55, 55]
# 10 A00296:241:HMWTTDRXX:1:1101:17797:6073 1:N:0:CGTACTAG/1_TCATCAATTTACGGTCA_CACATGATAGCT [70, 70, 119, 119]
# 11 A00296:241:HMWTTDRXX:1:1101:17815:6073 1:N:0:CGTACTAG/1_CAAATGAACAAGTTAGG_AACCGGTTGATG [70, 70, 42, 42]
# 12 A00296:241:HMWTTDRXX:1:1101:17906:6073 1:N:0:CGTACTAG/1_GATTTGTAGGAAATACG_CCCTTGTTTAAG [70, 70, 57, 57]
# 13 A00296:241:HMWTTDRXX:1:1101:17978:6073 1:N:0:CGTACTAG/1_TAGTTAATACCGTCAAG_AGTCCCGCAATC [70, 70, 74, 74]
# 14 A00296:241:HMWTTDRXX:1:1101:18069:6073 1:N:0:CGTACTAG/1_GTATTTTATGGCACTAG_CTATGTTGAAGG [70, 70, 150, 150]
# 15 A00296:241:HMWTTDRXX:1:1101:18087:6073 1:N:0:CGTACTAG/1_CTTAGGTCTTCAGAACT_AGCTCTGCTAAG [70, 70, 150, 150]
# 16 A00296:241:HMWTTDRXX:1:1101:18123:6073 1:N:0:CGTACTAG/1_CTTTTGACATGAGTTGA_TTCACTAGCAGA [70, 70, 84, 84]
# 17 A00296:241:HMWTTDRXX:1:1101:18195:6073 1:N:0:CGTACTAG/1_GATTTGGACGAATAAGC_GAGAATATTAAC [70, 70, 150, 150]
# 18 A00296:241:HMWTTDRXX:1:1101:18231:6073 1:N:0:CGTACTAG/1_GATATTGTTCCCCTTCG_GCAGTGGTGATG [70, 70, 150, 150]
# 19 A00296:241:HMWTTDRXX:1:1101:18322:6073 1:N:0:CGTACTAG/1_TACCGTATAGCAGTTCT_TTAGAAGTAATC [70, 70, 47, 47]
# 20 A00296:241:HMWTTDRXX:1:1101:18376:6073 1:N:0:CGTACTAG/1_CTCTATTGGCGATCTTA_GCCGCTTTGTTA [70, 70, 58, 58]
# 21 A00296:241:HMWTTDRXX:1:1101:18430:6073 1:N:0:CGTACTAG/1_CCTCATACCTGCAGACT_TAATGTGTGCGG [70, 70, 36, 36]
# 22 A00296:241:HMWTTDRXX:1:1101:18466:6073 1:N:0:CGTACTAG/1_AGAATGTAGCCTCGACA_GTCGTCATGGTC [70, 70, 113, 113]
# 23 A00296:241:HMWTTDRXX:1:1101:18484:6073 1:N:0:CGTACTAG/1_ACCTATAAATCCCAACG_AGCCAGGTGCAC [70, 70, 44, 44]
# 24 A00296:241:HMWTTDRXX:1:1101:18593:6073 1:N:0:CGTACTAG/1_GCTACTGACTGGCTTGT_AATAAAATGAAT [70, 70, 86, 86]
# 25 A00296:241:HMWTTDRXX:1:1101:18611:6073 1:N:0:CGTACTAG/1_GATTTGAAACTTCAATA_GCAGGGCTCACA [70, 70, 41, 41]
# 26 A00296:241:HMWTTDRXX:1:1101:18701:6073 1:N:0:CGTACTAG/1_AGAATGTCTTCAACTAG_TAGACTGTTCAC [70, 70, 43, 43]
# 27 A00296:241:HMWTTDRXX:1:1101:18756:6073 1:N:0:CGTACTAG/1_AAATTGTGAGGTAATGC_GAGACGGTTTAG [70, 70, 150, 150]
# 28 A00296:241:HMWTTDRXX:1:1101:18846:6073 1:N:0:CGTACTAG/1_CTTTTGTTGAGCGAACT_AATCGCATCCTT [70, 70, 48, 48]
# 29 A00296:241:HMWTTDRXX:1:1101:18900:6073 1:N:0:CGTACTAG/1_CAATGGTACCGTGCTAA_CTGTTCCCCGGG [70, 70, 150, 150]
# 30 A00296:241:HMWTTDRXX:1:1101:18973:6073 1:N:0:CGTACTAG/1_CTGGATAAAGTACATAA_GCTCACATGCGA [70, 70, 150, 150]
# 31 A00296:241:HMWTTDRXX:1:1101:19190:6073 1:N:0:CGTACTAG/1_TCAACTTATGGCACTCT_TAACCGTTAGGA [70, 70, 42, 42]
# 32 A00296:241:HMWTTDRXX:1:1101:19226:6073 1:N:0:CGTACTAG/1_AATATGACATGAGATAC_CACCGTTTGCAC [70, 70, 150, 150]
# 33 A00296:241:HMWTTDRXX:1:1101:19533:6073 1:N:0:CGTACTAG/1_GACTTATTGACTAGATC_TCCAGTATGAGG [70, 70, 150, 150]
# 34 A00296:241:HMWTTDRXX:1:1101:19587:6073 1:N:0:CGTACTAG/1_GCTTCATGTTAAGCACG_ATAGATTTACCA [70, 70, 150, 150]
# 35 A00296:241:HMWTTDRXX:1:1101:19605:6073 1:N:0:CGTACTAG/1_GACTTATAATTTTGACG_GGATATGTACGC [70, 70, 66, 66]
# 36 A00296:241:HMWTTDRXX:1:1101:19660:6073 1:N:0:CGTACTAG/1_TAATCGAAACTTGGTTG_ATGAGTCCCCAC [70, 70, 150, 150]
# 37 A00296:241:HMWTTDRXX:1:1101:19696:6073 1:N:0:CGTACTAG/1_TCCTCTAAATCCAATTG_ATTCTTTTCCGC [70, 70, 72, 72]
# 38 A00296:241:HMWTTDRXX:1:1101:19804:6073 1:N:0:CGTACTAG/1_GCAACAATTCAGTCAAG_TGCTCATTCACC [70, 70, 150, 150]
# 39 A00296:241:HMWTTDRXX:1:1101:19840:6073 1:N:0:CGTACTAG/1_ACTTTGATACCGCGAAT_TCTACGTTATTC [70, 70, 44, 44]
# 40 A00296:241:HMWTTDRXX:1:1101:19895:6073 1:N:0:CGTACTAG/1_ACTCAGAAGGCCGTAGC_GCTACTGTCGAA [70, 70, 92, 92]
# 41 A00296:241:HMWTTDRXX:1:1101:19949:6073 1:N:0:CGTACTAG/1_AGAGAGGTGCAAGAACT_GGTTTTGTTATA [70, 70, 150, 150]
# 42 A00296:241:HMWTTDRXX:1:1101:19967:6073 1:N:0:CGTACTAG/1_TTTTATGACCATCTACT_AGTAGCGTGGAT [70, 70, 150, 150]
# 43 A00296:241:HMWTTDRXX:1:1101:20148:6073 1:N:0:CGTACTAG/1_GCTACTGACTGGCTTGT_TAGCGGCGACCC [70, 70, 30, 30]
# 44 A00296:241:HMWTTDRXX:1:1101:20166:6073 1:N:0:CGTACTAG/1_TCTTTTGTTCCCACAGC_CGTAGAATAGCT [70, 70, 150, 150]
# 45 A00296:241:HMWTTDRXX:1:1101:20220:6073 1:N:0:CGTACTAG/1_TCATCAGAACAATCACT_TGGTATATTCTT [70, 70, 98, 98]
# 46 A00296:241:HMWTTDRXX:1:1101:20274:6073 1:N:0:CGTACTAG/1_AACTAGAAGGCCCATGG_AGGATTTGCCCG [70, 70, 95, 95]
# 47 A00296:241:HMWTTDRXX:1:1101:20292:6073 1:N:0:CGTACTAG/1_TTATTGAAAATGATAAC_GGCATTTTGACC [70, 70, 150, 150]
# 48 A00296:241:HMWTTDRXX:1:1101:20311:6073 1:N:0:CGTACTAG/1_GGAACTTTCGGCGTTAG_CTGTTCGTAAGT [70, 70, 81, 81]
# 49 A00296:241:HMWTTDRXX:1:1101:20383:6073 1:N:0:CGTACTAG/1_CATTCTTAAGCTTAACA_GGTAACTTAGGC [70, 70, 150, 150]
# 50 A00296:241:HMWTTDRXX:1:1101:20455:6073 1:N:0:CGTACTAG/1_CAAATGATTCCTTAACA_CTGTTTATATGG [70, 70, 59, 59]
# 51 A00296:241:HMWTTDRXX:1:1101:20473:6073 1:N:0:CGTACTAG/1_TTATTGAATTTCATACG_TTCATCTTGCGG [70, 70, 150, 150]
# 52 A00296:241:HMWTTDRXX:1:1101:20582:6073 1:N:0:CGTACTAG/1_TGATGGAACAAGAGAAG_GCTCTCCTAATC [70, 70, 150, 150]
# 53 A00296:241:HMWTTDRXX:1:1101:20745:6073 1:N:0:CGTACTAG/1_ACTCAGTGATGACGTCT_ATCAGAACGTCT [70, 70, 150, 150]
# 54 A00296:241:HMWTTDRXX:1:1101:20763:6073 1:N:0:CGTACTAG/1_AAATGTAGAATTCTTCG_AGAATTGTCACG [70, 70, 82, 82]
# 55 A00296:241:HMWTTDRXX:1:1101:20781:6073 1:N:0:CGTACTAG/1_AAATTGTGGCGATGATA_ACACTAACGCCA [70, 70, 94, 94]
# 56 A00296:241:HMWTTDRXX:1:1101:20961:6073 1:N:0:CGTACTAG/1_TCCTCTATCCGGTATTC_CTCTTGGGGTTC [70, 70, 150, 150]
# 57 A00296:241:HMWTTDRXX:1:1101:21070:6073 1:N:0:CGTACTAG/1_TTCGATAGCTTATCTAC_TTGTAACGGCAG [70, 70, 150, 150]
# 58 A00296:241:HMWTTDRXX:1:1101:21106:6073 1:N:0:CGTACTAG/1_AACCTGGATGCATGTCC_ACCCATCTCGCT [70, 70, 150, 150]
# 59 A00296:241:HMWTTDRXX:1:1101:21197:6073 1:N:0:CGTACTAG/1_AGAATGTTTACGGATTA_AACTTATAACTG [70, 70, 150, 150]
# 60 A00296:241:HMWTTDRXX:1:1101:21269:6073 1:N:0:CGTACTAG/1_TCCTGAGTTCCCCTTCG_ATAAATGTGCGT [70, 70, 150, 150]
# 61 A00296:241:HMWTTDRXX:1:1101:21287:6073 1:N:0:CGTACTAG/1_GATGGATAGGAAGTTCT_TACGACCTGCAG [70, 70, 150, 150]
# 62 A00296:241:HMWTTDRXX:1:1101:21377:6073 1:N:0:CGTACTAG/1_GCTACTTATGGCGTACA_CCCCTATTGCCG [70, 70, 150, 150]
# 63 A00296:241:HMWTTDRXX:1:1101:21558:6073 1:N:0:CGTACTAG/1_CACCATATTTACAGAAG_CGCGGAATGAAG [70, 70, 150, 150]
# 64 A00296:241:HMWTTDRXX:1:1101:21594:6073 1:N:0:CGTACTAG/1_TTTGGGATTCCTTGTCC_TCGCTCGTTCCA [70, 70, 150, 150]
# 65 A00296:241:HMWTTDRXX:1:1101:21667:6073 1:N:0:CGTACTAG/1_AACTAGTATGGCTCATC_GGCAGTTGTCTA [70, 70, 150, 150]
# 66 A00296:241:HMWTTDRXX:1:1101:21721:6073 1:N:0:CGTACTAG/1_AGAATGTTTACGGATTA_TGCTAGGTAGTA [70, 70, 150, 150]
# 67 A00296:241:HMWTTDRXX:1:1101:21739:6073 1:N:0:CGTACTAG/1_ACTCAGCTGTTTCTAAG_AGAATATGGTAC [70, 70, 150, 150]
# 68 A00296:241:HMWTTDRXX:1:1101:21757:6073 1:N:0:CGTACTAG/1_GTTCCAGTTCCCACTAG_AGTTCAATACAT [70, 70, 38, 38]
# 69 A00296:241:HMWTTDRXX:1:1101:21811:6073 1:N:0:CGTACTAG/1_ACCTATTATGGCGTAGC_GGAACGGTTTGG [70, 70, 78, 78]
# 70 A00296:241:HMWTTDRXX:1:1101:21866:6073 1:N:0:CGTACTAG/1_CCTCATGAACCCCTAAG_CGGAGAGTTTAA [70, 70, 150, 150]
# 71 A00296:241:HMWTTDRXX:1:1101:21884:6073 1:N:0:CGTACTAG/1_AGAATGTTTACGGATTA_TGCTAGGTAGTA [70, 70, 150, 150]
# 72 A00296:241:HMWTTDRXX:1:1101:21938:6073 1:N:0:CGTACTAG/1_CTTGGAGCCTCTCGAAT_ATGTATACGTAC [70, 70, 150, 150]
# 73 A00296:241:HMWTTDRXX:1:1101:21956:6073 1:N:0:CGTACTAG/1_CATCAGAACTTTAGTCG_TAGCATATGCGC [70, 70, 150, 150]
# 74 A00296:241:HMWTTDRXX:1:1101:22083:6073 1:N:0:CGTACTAG/1_CGAATTATACCGCAAGT_GGATTGGTGCAG [70, 70, 75, 75]
# 75 A00296:241:HMWTTDRXX:1:1101:22426:6073 1:N:0:CGTACTAG/1_CTAAGAATTCAGGAACT_CACTTCATTCGG [70, 70, 55, 55]
# 76 A00296:241:HMWTTDRXX:1:1101:22535:6073 1:N:0:CGTACTAG/1_GGATGAAAAATGCGACA_GTTTATTTGGTG [70, 70, 84, 84]
# 77 A00296:241:HMWTTDRXX:1:1101:22607:6073 1:N:0:CGTACTAG/1_ACAACGAACTTTAATCA_AGTACTATCACC [70, 70, 150, 150]
# 78 A00296:241:HMWTTDRXX:1:1101:22733:6073 1:N:0:CGTACTAG/1_AACTGATGATGAGGATT_ATTTCGTTCGGT [70, 70, 69, 69]
# 79 A00296:241:HMWTTDRXX:1:1101:22824:6073 1:N:0:CGTACTAG/1_CTTTTGAAATCCTTATT_CTGGACCTCGAG [70, 70, 58, 58]
# 80 A00296:241:HMWTTDRXX:1:1101:22860:6073 1:N:0:CGTACTAG/1_TCTTTTGCCTCTGTTCT_TCAATATTTAAG [70, 70, 76, 76]
# 81 A00296:241:HMWTTDRXX:1:1101:22878:6073 1:N:0:CGTACTAG/1_GCTTCAAGTCACTATGA_GTCTCTGTGGTG [70, 70, 150, 150]
# 82 A00296:241:HMWTTDRXX:1:1101:22914:6073 1:N:0:CGTACTAG/1_AATACAATCGAGAGTGT_GCGGTTTTATCC [70, 70, 150, 150]
# 83 A00296:241:HMWTTDRXX:1:1101:23131:6073 1:N:0:CGTACTAG/1_GTTCCATACCGTAATTG_AAGACATTCTGT [70, 70, 150, 150]
# 84 A00296:241:HMWTTDRXX:1:1101:23149:6073 1:N:0:CGTACTAG/1_TCAGATAGCTTATGATA_GGATTTTGACCA [70, 70, 68, 68]
# 85 A00296:241:HMWTTDRXX:1:1101:23258:6073 1:N:0:CGTACTAG/1_AAACATTGGTGCCTAAG_AAGATGCTCTTT [70, 70, 150, 150]
# 86 A00296:241:HMWTTDRXX:1:1101:23366:6073 1:N:0:CGTACTAG/1_GACTTAAATTTCTGATA_GCGGGTCCGTTA [70, 70, 150, 150]
# 87 A00296:241:HMWTTDRXX:1:1101:23457:6073 1:N:0:CGTACTAG/1_TTCACGAGAATTATATA_AATGTTCTGACC [70, 70, 150, 150]
# 88 A00296:241:HMWTTDRXX:1:1101:23583:6073 1:N:0:CGTACTAG/1_TTATTGGAAATCATATA_TCCGTCAGAAAC [70, 70, 150, 150]
# 89 A00296:241:HMWTTDRXX:1:1101:23818:6073 1:N:0:CGTACTAG/1_CACCATATACCGCTTGT_TTCTGTTTGGAT [70, 70, 31, 31]
# 90 A00296:241:HMWTTDRXX:1:1101:23927:6073 1:N:0:CGTACTAG/1_CTGATGAAATCCTATAG_GTTGTCTTAGGG [70, 70, 85, 85]
# 91 A00296:241:HMWTTDRXX:1:1101:24017:6073 1:N:0:CGTACTAG/1_TTCACGAAGCGTAATGC_TCAAGGTGAGTT [70, 70, 150, 150]
# 92 A00296:241:HMWTTDRXX:1:1101:24270:6073 1:N:0:CGTACTAG/1_CTCATAATGGATCGACA_CTAATTCTCGAG [70, 70, 150, 150]
# 93 A00296:241:HMWTTDRXX:1:1101:24306:6073 1:N:0:CGTACTAG/1_AGAATGTTTACGGATTA_GATCGTTATGAA [70, 70, 150, 150]
# 94 A00296:241:HMWTTDRXX:1:1101:24451:6073 1:N:0:CGTACTAG/1_TCAACTTAATTTAATCA_CTGTGTGTACCC [70, 70, 150, 150]
# 95 A00296:241:HMWTTDRXX:1:1101:24614:6073 1:N:0:CGTACTAG/1_AACTTTGACTGGCATAA_CATGATATGGGC [70, 70, 84, 84]
# 96 A00296:241:HMWTTDRXX:1:1101:24885:6073 1:N:0:CGTACTAG/1_CTGGATATTCAGCTTCG_CGATATGTGACG [70, 70, 115, 115]
# 97 A00296:241:HMWTTDRXX:1:1101:25066:6073 1:N:0:CGTACTAG/1_GACATGACCTGCAATTG_TGTTTCATGATT [70, 70, 43, 43]
# 98 A00296:241:HMWTTDRXX:1:1101:25138:6073 1:N:0:CGTACTAG/1_CTCTATTGAACACATCC_ATCCTAGTCGCA [70, 70, 150, 150]
# 99 A00296:241:HMWTTDRXX:1:1101:25265:6073 1:N:0:CGTACTAG/1_CAATGGTTCGGCTTATT_ACCGGTTTGGGG [70, 70, 83, 83]
# 100 A00296:241:HMWTTDRXX:1:1101:25301:6073 1:N:0:CGTACTAG/1_CATCAGAAATCCAGAAG_GCGTATGTGGTG [70, 70, 150, 150]
# 101 A00296:241:HMWTTDRXX:1:1101:25500:6073 1:N:0:CGTACTAG/1_AGTATTTAGGAAACTAG_ATTCAAATTGAT [70, 70, 150, 150]
# 102 A00296:241:HMWTTDRXX:1:1101:25572:6073 1:N:0:CGTACTAG/1_GATATTGAGGTACTAAG_TGGAACTGACGA [70, 70, 39, 39]
# 103 A00296:241:HMWTTDRXX:1:1101:25681:6073 1:N:0:CGTACTAG/1_CAAACTTACTCCGAATC_GAGTGTGTGTGA [70, 70, 88, 88]
# 104 A00296:241:HMWTTDRXX:1:1101:25735:6073 1:N:0:CGTACTAG/1_TTTGGGTTAAGGACAGC_TAAGCTATGACT [70, 70, 88, 88]
# 105 A00296:241:HMWTTDRXX:1:1101:25843:6073 1:N:0:CGTACTAG/1_AACCTGTGGTGCTTAGG_TTGTGGTTAGAG [70, 70, 115, 115]
# 106 A00296:241:HMWTTDRXX:1:1101:25861:6073 1:N:0:CGTACTAG/1_TTTGGGTTAAGGACAGC_TGTATGTTGCGC [70, 70, 150, 150]
# 107 A00296:241:HMWTTDRXX:1:1101:26060:6073 1:N:0:CGTACTAG/1_TTCGATAACCTGGTACA_CGCGGGTTGGAG [70, 70, 91, 91]
# 108 A00296:241:HMWTTDRXX:1:1101:26096:6073 1:N:0:CGTACTAG/1_GATGGATATGGCAGTCG_TGGGTCGTGAAA [70, 70, 59, 59]
# 109 A00296:241:HMWTTDRXX:1:1101:26133:6073 1:N:0:CGTACTAG/1_TCATCATACTCCGAACT_TATTATGTAGTC [70, 70, 104, 104]
# 110 A00296:241:HMWTTDRXX:1:1101:26205:6073 1:N:0:CGTACTAG/1_CTCATATTGGCCACAGC_CAGCTTGTGAGG [70, 70, 103, 103]
# 111 A00296:241:HMWTTDRXX:1:1101:26223:6073 1:N:0:CGTACTAG/1_CATCAGTTCGGCGTAGC_GTTTCAGTGCGT [70, 70, 150, 150]
# 112 A00296:241:HMWTTDRXX:1:1101:26476:6073 1:N:0:CGTACTAG/1_AACTAGTACTCCAGTAC_GTGGCATCAAGG [70, 70, 150, 150]
# 113 A00296:241:HMWTTDRXX:1:1101:26512:6073 1:N:0:CGTACTAG/1_CTTAGGTTAAGGTGATA_GTGAATCTGGAT [70, 70, 88, 88]
# 114 A00296:241:HMWTTDRXX:1:1101:26530:6073 1:N:0:CGTACTAG/1_GTTCTTGTGCAATTAGG_CTTATCTTAAGA [70, 70, 150, 150]
# 115 A00296:241:HMWTTDRXX:1:1101:26585:6073 1:N:0:CGTACTAG/1_TCCTGAGCCTCTGATCG_TTTGCTCTTGGA [70, 70, 82, 82]
# 116 A00296:241:HMWTTDRXX:1:1101:26639:6073 1:N:0:CGTACTAG/1_TACCGTATGAGGGGTTG_CTATATTTGTGT [70, 70, 99, 99]
# 117 A00296:241:HMWTTDRXX:1:1101:26747:6073 1:N:0:CGTACTAG/1_CTTTTGCTTCCAGATAC_CCTTCCGTCCTT [70, 70, 150, 150]
# 118 A00296:241:HMWTTDRXX:1:1101:26784:6073 1:N:0:CGTACTAG/1_TCAACTTAATTTAATCA_ACTTTCGTTTAG [70, 70, 150, 150]
# 119 A00296:241:HMWTTDRXX:1:1101:26802:6073 1:N:0:CGTACTAG/1_TCCCTATTAAGGAGACT_TTTCTCCTGGAG [70, 70, 150, 150]
# 120 A00296:241:HMWTTDRXX:1:1101:26856:6073 1:N:0:CGTACTAG/1_AACTTTGACTGGCATAA_GGTTTTTTGGTT [70, 70, 150, 150]
# 121 A00296:241:HMWTTDRXX:1:1101:26982:6073 1:N:0:CGTACTAG/1_CCTCATACCTGCAGACT_GAGTTAATTGGC [70, 70, 150, 150]
# 122 A00296:241:HMWTTDRXX:1:1101:27145:6073 1:N:0:CGTACTAG/1_TGATGGTTCGGCTTACC_TCCGTTGAGCAG [70, 70, 150, 150]
# 123 A00296:241:HMWTTDRXX:1:1101:27199:6073 1:N:0:CGTACTAG/1_CCTCTAATTTACACACA_CGAGTTTATAAC [70, 70, 49, 49]
# 124 A00296:241:HMWTTDRXX:1:1101:27308:6073 1:N:0:CGTACTAG/1_AAACATTAGGAAAGTGT_AATTGTACGGAC [70, 70, 150, 150]
# 125 A00296:241:HMWTTDRXX:1:1101:27344:6073 1:N:0:CGTACTAG/1_CGAATTACCTGCAGTTA_GTGACATGCGGT [70, 70, 89, 89]
# 126 A00296:241:HMWTTDRXX:1:1101:27489:6073 1:N:0:CGTACTAG/1_CATCAGTGTTAACTATC_GTGTATCTCCAG [70, 70, 80, 80]
# 127 A00296:241:HMWTTDRXX:1:1101:27670:6073 1:N:0:CGTACTAG/1_GTTCTTCTTGGCTCAAG_ACGTAAATAGAC [70, 70, 72, 72]
# 128 A00296:241:HMWTTDRXX:1:1101:27706:6073 1:N:0:CGTACTAG/1_CTCATATTGGCCACAGC_TTTTATCTGAGC [70, 70, 150, 150]
# 129 A00296:241:HMWTTDRXX:1:1101:27832:6073 1:N:0:CGTACTAG/1_TCAGATAAAGATGATAC_AGTAAACCCGGC [70, 70, 150, 150]
# 130 A00296:241:HMWTTDRXX:1:1101:27887:6073 1:N:0:CGTACTAG/1_GATTTGTGGTGCGATGT_GTTTCATGGGGG [70, 70, 44, 44]
# 131 A00296:241:HMWTTDRXX:1:1101:27923:6073 1:N:0:CGTACTAG/1_TCTTTTGTTCCCACAGC_TCGTATTGGGCG [70, 70, 150, 150]
# 132 A00296:241:HMWTTDRXX:1:1101:27977:6073 1:N:0:CGTACTAG/1_GATGGAATCGAGTCTTA_TACAAATACGAG [70, 70, 150, 150]

# %% [markdown]
# Everything above seems to be working and the stuff below is "legacy" from the time spent building the above.

# %%
import yaml
from read_breaker_parser import ReadParser
import bagpipe_config as bconfig # Still needed to get FASTQ paths

# --- Configuration ---
# Still load the old config *just* to get the sample file paths
bagpipe_yaml = "../bagpipe_config.yaml" # Path to original bagpipe config
bagpipe_config_data = bconfig.load_config(bagpipe_yaml)

# Path to the NEW read_breaker YAML configuration
read_breaker_yaml_path = "../configs/bagpipe_2N.yaml" # Adjust path as needed

# Load the read_breaker configuration
try:
    with open(read_breaker_yaml_path, 'r') as f:
        read_breaker_config = yaml.safe_load(f)
    print("Successfully loaded read_breaker config.")
except FileNotFoundError:
    print(f"ERROR: read_breaker config file not found at {read_breaker_yaml_path}")
    read_breaker_config = None
except Exception as e:
    print(f"ERROR: Failed to load or parse read_breaker config: {e}")
    read_breaker_config = None

# Instantiate the new ReadParser
if read_breaker_config:
    # ReadParser expects the full config dict.
    # It automatically looks for 'pipeline' and 'params' keys if globals_cfg is not explicitly passed.
    # 2. Initialize parser with the new structure
    read_parser = ReadParser(
        pipeline_cfg={"pipeline": read_breaker_config["pipeline"]},
        globals_cfg=read_breaker_config["params"],
        globals_namespace="params",
        base_dir = "../"
    )
    print("ReadParser initialized.")
else:
    read_parser = None
    print("ReadParser could not be initialized.")

print(read_parser)
# Out:
# Successfully loaded read_breaker config.
# Loaded 95 barcodes for bc1
# Loaded 96 barcodes for bc2
# Loaded 96 barcodes for bc3
# ReadParser initialized.
# ReadParser Pipeline:
# [  0 ]  check_upstream_motif_r1: hamming_test (read 1, must pass: True)
# [  1 ]  extract_bc3: extract (read 1, must pass: False)
# [  2 ]  extract_bc2: extract (read 1, must pass: False)
# [  3 ]  extract_bc1: extract (read 1, must pass: False)
# [  4 ]  good_barcodes: test ({{ bc1_match and bc2_match and bc3_match }}, must pass: True)
# [  5 ]  extract_vt3: extract (read 1, must pass: True)
# [  6 ]  extract_vt2: extract (read 1, must pass: True)
# [  7 ]  extract_vt1: extract (read 1, must pass: True)
# [  8 ]  find_adapter_r1: regex_search (read 1, must pass: False)
# [  9 ]  find_polya_r1: regex_search (read 1, must pass: False)
# [ 10 ]  find_adapter_r2: regex_search (read 2, must pass: False)
# [ 11 ]  compute_end_r1: compute ({{ (adapter1_start - params.trim_offset_r1) if adapter1_start else (polya_start if polya_start else len_seq1) }}, must pass: True)
# [ 12 ]  compute_end_r2: compute ({{ (adapter2_start - params.trim_offset_r2) if adapter2_start is not none else len_seq2 }}, must pass: True)
# [ 13 ]  check_read_lens: test ({{(end_r1 >= params.min_read_length_r1 and end_r2 >= params.min_read_length_r2)}}, must pass: True)
# [ 14 ]  assemble_bead_tag: compute ({{ bc3 ~ bc2 ~ bc1 }}, must pass: True)
# [ 15 ]  assemble_varietal_tag: compute ({{ vt3 ~ vt2 ~ vt1 }}, must pass: True)
# [ 16 ]  assemble_read_tag: compute ({{ bead_tag ~ '_' ~ varietal_tag }}, must pass: True)

# %%
print(read_parser.get_parse_log())
from read_breaker_io import FastqReader # Make sure to use the new reader import

# Get paths from the previously loaded bagpipe_config_data
sample_info = bagpipe_config_data.get("samples", [])[0]
path1 = sample_info["fastq_r1"]
path2 = sample_info["fastq_r2"]
print(f"Processing R1: {path1}")
print(f"Processing R2: {path2}")

read_count = 0
processed_count = 0
max_reads_to_show = 50 # Limit output for demonstration


good_rows = []
bad_rows = []
# Use the FastqReader from read_breaker_io
with FastqReader(path1, path2, trim_tail=True) as read_walker:
    for read_pair in read_walker:
        read_count += 1
        # New parser takes the same arguments (read_id, seq1, qual1, seq2, qual2)
        # It returns a dictionary or potentially None/fail-dict on failure
        result_dict = read_parser.parse(*read_pair)
        if result_dict and result_dict.get("status") == "ok":
            # Successfully parsed according to the pipeline
            processed_count += 1
            good_rows.append(result_dict)
            # --- Next Steps (outside read_breaker parser) ---
            # 1. Construct new read ID using extracted tags (e.g., result_dict['bc1'], etc.)
            # new_id = f"{result_dict['read_id']}/1_{result_dict['bc3']}{result_dict['bc2']}..."
            # 2. Perform trimming based on results or separate logic
            # trimmed_seq1, trimmed_qual1 = trim_logic(read_pair[1], read_pair[2], result_dict)
            # 3. Write output using FastqWriter
            # writer.write((new_id, trimmed_seq1, ...))
        elif result_dict and result_dict.get("status") == "fail":
            bad_rows.append(result_dict)
            print(f"Read {read_count} FAIL: {result_dict['message']}")
        else:
            print(f"Read {read_count} FAIL: Parser returned unexpected value: {result_dict}")

print(f"\nFinished processing. Total reads: {read_count}, Successfully parsed: {processed_count}")
# Print final parsing stats from the parser instance
print("\nParser Stats:")
print(read_parser.get_parse_log())
# Out:
# {'total_reads': 0, 'successful_reads': 0, 'failed_reads': 0, 'failures_by_step': {'check_upstream_motif_r1': 0, 'extract_bc3': 0, 'extract_bc2': 0, 'extract_bc1': 0, 'good_barcodes': 0, 'extract_vt3': 0, 'extract_vt2': 0, 'extract_vt1': 0, 'find_adapter_r1': 0, 'find_polya_r1': 0, 'find_adapter_r2': 0, 'compute_end_r1': 0, 'compute_end_r2': 0, 'check_read_lens': 0, 'assemble_bead_tag': 0, 'assemble_varietal_tag': 0, 'assemble_read_tag': 0}}
# Processing R1: ../data/test_data/r1_new2N.fastq.gz
# Processing R2: ../data/test_data/r2_new2N.fastq.gz
# Read 4 FAIL: Test operation failed
# Read 9 FAIL: Hamming_test operation failed
# Read 11 FAIL: Hamming_test operation failed
# Read 12 FAIL: Hamming_test operation failed
# Read 13 FAIL: Hamming_test operation failed
# Read 16 FAIL: Hamming_test operation failed
# Read 17 FAIL: Test operation failed
# Read 22 FAIL: Test operation failed
# Read 26 FAIL: Test operation failed
# Read 29 FAIL: Hamming_test operation failed
# Read 31 FAIL: Test operation failed
# Read 33 FAIL: Test operation failed
# Read 37 FAIL: Hamming_test operation failed
# Read 42 FAIL: Hamming_test operation failed
# Read 43 FAIL: Test operation failed
# Read 47 FAIL: Hamming_test operation failed
# Read 48 FAIL: Hamming_test operation failed
# Read 49 FAIL: Hamming_test operation failed
# Read 52 FAIL: Hamming_test operation failed
# Read 53 FAIL: Hamming_test operation failed
# Read 54 FAIL: Hamming_test operation failed
# Read 55 FAIL: Hamming_test operation failed
# Read 56 FAIL: Test operation failed
# Read 58 FAIL: Hamming_test operation failed
# Read 61 FAIL: Hamming_test operation failed
# Read 64 FAIL: Hamming_test operation failed
# Read 67 FAIL: Hamming_test operation failed
# Read 71 FAIL: Hamming_test operation failed
# Read 75 FAIL: Hamming_test operation failed
# Read 76 FAIL: Hamming_test operation failed
# Read 83 FAIL: Hamming_test operation failed
# Read 85 FAIL: Test operation failed
# Read 89 FAIL: Hamming_test operation failed
# Read 90 FAIL: Hamming_test operation failed
# Read 91 FAIL: Hamming_test operation failed
# Read 92 FAIL: Hamming_test operation failed
# Read 96 FAIL: Hamming_test operation failed
# Read 97 FAIL: Test operation failed
# Read 99 FAIL: Hamming_test operation failed
# Read 102 FAIL: Hamming_test operation failed
# Read 104 FAIL: Hamming_test operation failed
# Read 108 FAIL: Hamming_test operation failed
# Read 112 FAIL: Hamming_test operation failed
# Read 116 FAIL: Hamming_test operation failed
# Read 119 FAIL: Hamming_test operation failed
# Read 121 FAIL: Test operation failed
# Read 122 FAIL: Hamming_test operation failed
# Read 123 FAIL: Hamming_test operation failed
# Read 124 FAIL: Hamming_test operation failed
# Read 125 FAIL: Hamming_test operation failed
# Read 126 FAIL: Hamming_test operation failed
# Read 127 FAIL: Hamming_test operation failed
# Read 128 FAIL: Hamming_test operation failed
# Read 130 FAIL: Hamming_test operation failed
# Read 131 FAIL: Test operation failed
# Read 134 FAIL: Hamming_test operation failed
# Read 136 FAIL: Hamming_test operation failed
# Read 137 FAIL: Test operation failed
# Read 138 FAIL: Hamming_test operation failed
# Read 140 FAIL: Hamming_test operation failed
# Read 144 FAIL: Hamming_test operation failed
# Read 145 FAIL: Hamming_test operation failed
# Read 146 FAIL: Hamming_test operation failed
# Read 147 FAIL: Hamming_test operation failed
# Read 148 FAIL: Hamming_test operation failed
# Read 149 FAIL: Test operation failed
# Read 153 FAIL: Hamming_test operation failed
# Read 155 FAIL: Hamming_test operation failed
# Read 157 FAIL: Hamming_test operation failed
# Read 158 FAIL: Hamming_test operation failed
# Read 160 FAIL: Hamming_test operation failed
# Read 161 FAIL: Hamming_test operation failed
# Read 163 FAIL: Hamming_test operation failed
# Read 166 FAIL: Hamming_test operation failed
# Read 167 FAIL: Hamming_test operation failed
# Read 168 FAIL: Hamming_test operation failed
# Read 169 FAIL: Hamming_test operation failed
# Read 172 FAIL: Test operation failed
# Read 174 FAIL: Test operation failed
# Read 175 FAIL: Test operation failed
# Read 177 FAIL: Hamming_test operation failed
# Read 178 FAIL: Hamming_test operation failed
# Read 179 FAIL: Hamming_test operation failed
# Read 180 FAIL: Test operation failed
# Read 182 FAIL: Test operation failed
# Read 183 FAIL: Hamming_test operation failed
# Read 185 FAIL: Hamming_test operation failed
# Read 187 FAIL: Test operation failed
# Read 190 FAIL: Test operation failed
# Read 191 FAIL: Test operation failed
# Read 192 FAIL: Test operation failed
# Read 194 FAIL: Hamming_test operation failed
# Read 195 FAIL: Test operation failed
# Read 196 FAIL: Hamming_test operation failed
# Read 198 FAIL: Hamming_test operation failed
# Read 199 FAIL: Hamming_test operation failed
# Read 201 FAIL: Test operation failed
# Read 202 FAIL: Hamming_test operation failed
# Read 204 FAIL: Test operation failed
# Read 207 FAIL: Test operation failed
# Read 208 FAIL: Test operation failed
# Read 212 FAIL: Hamming_test operation failed
# Read 215 FAIL: Hamming_test operation failed
# Read 219 FAIL: Hamming_test operation failed
# Read 221 FAIL: Test operation failed
# Read 223 FAIL: Hamming_test operation failed
# Read 227 FAIL: Hamming_test operation failed
# Read 230 FAIL: Test operation failed
# Read 231 FAIL: Test operation failed
# Read 233 FAIL: Hamming_test operation failed
# Read 236 FAIL: Hamming_test operation failed
# Read 237 FAIL: Hamming_test operation failed
# Read 239 FAIL: Hamming_test operation failed
# Read 240 FAIL: Test operation failed
# Read 243 FAIL: Hamming_test operation failed
# Read 244 FAIL: Hamming_test operation failed
# Read 245 FAIL: Test operation failed
# Read 247 FAIL: Hamming_test operation failed
#
# Finished processing. Total reads: 250, Successfully parsed: 132
#
# Parser Stats:
# {'total_reads': 250, 'successful_reads': 132, 'failed_reads': 118, 'failures_by_step': {'check_upstream_motif_r1': 85, 'extract_bc3': 1, 'extract_bc2': 2, 'extract_bc1': 4, 'good_barcodes': 6, 'extract_vt3': 0, 'extract_vt2': 0, 'extract_vt1': 0, 'find_adapter_r1': 156, 'find_polya_r1': 159, 'find_adapter_r2': 71, 'compute_end_r1': 0, 'compute_end_r2': 0, 'check_read_lens': 27, 'assemble_bead_tag': 0, 'assemble_varietal_tag': 0, 'assemble_read_tag': 0}, 'success_rate': 52.8}

# %%
read_parser.regex_patterns
# Out:
# {'adapter_r1': re.compile(r'CCAAACACACCCAA|(CCAA|CCAAA|CCAAAC|CCAAACA|CCAAACAC|CCAAACACA|CCAAACACAC|CCAAACACACC|CCAAACACACCC|CCAAACACACCCA|CCAAACACACCCAA)$',
#             re.UNICODE),
#  'polyA_tail': re.compile(r'AAAAAAAAAAAAAA', re.UNICODE),
#  'adapter_r2': re.compile(r'GAGCGGACTCTGCG|(GAGC|GAGCG|GAGCGG|GAGCGGA|GAGCGGAC|GAGCGGACT|GAGCGGACTC|GAGCGGACTCT|GAGCGGACTCTG|GAGCGGACTCTGC|GAGCGGACTCTGCG)$',
#             re.UNICODE)}

# %%
import pandas as pd


df_good = pd.DataFrame(good_rows)
df_bad = pd.DataFrame(bad_rows)
df_good
# Out:
#                                     read_id  len_seq1  len_seq2  motif_ok  \
# 0    A00296:241:HMWTTDRXX:1:1101:17201:6073       150       150      True
# 1    A00296:241:HMWTTDRXX:1:1101:17219:6073       150       150      True
# 2    A00296:241:HMWTTDRXX:1:1101:17255:6073       150       150      True
# 3    A00296:241:HMWTTDRXX:1:1101:17291:6073       150       150      True
# 4    A00296:241:HMWTTDRXX:1:1101:17327:6073       150       150      True
# ..                                      ...       ...       ...       ...
# 127  A00296:241:HMWTTDRXX:1:1101:27706:6073       150       150      True
# 128  A00296:241:HMWTTDRXX:1:1101:27832:6073       150       150      True
# 129  A00296:241:HMWTTDRXX:1:1101:27887:6073       150       150      True
# 130  A00296:241:HMWTTDRXX:1:1101:27923:6073       150       150      True
# 131  A00296:241:HMWTTDRXX:1:1101:27977:6073       150       150      True
#
#         bc3  bc3_match     bc2  bc2_match    bc1  bc1_match  ...  \
# 0    CTGTTA       True  GTTCCC       True  ACTTC       True  ...
# 1    CTAAGA       True  ATTTAC       True  CGTGA       True  ...
# 2    TCTGGA       True  ATACCG       True  TGTAA       True  ...
# 3    GCTACT       True  GAAGCG       True  GGTCA       True  ...
# 4    TGATGG       True  ATTCAG       True  ATTCC       True  ...
# ..      ...        ...     ...        ...    ...        ...  ...
# 127  CTCATA       True  TTGGCC       True  ACAGC       True  ...
# 128  TCAGAT       True  AAAGAT       True  GATAC       True  ...
# 129  GATTTG       True  TGGTGC       True  GATGT       True  ...
# 130  TCTTTT       True  GTTCCC       True  ACAGC       True  ...
# 131  GATGGA       True  ATCGAG       True  TCTTA       True  ...
#
#      adapter1_start polya_start adapter2_start end_r1 end_r2 read_lens_ok  \
# 0              None        None            NaN    150    150         True
# 1              None        None           71.0    150     46         True
# 2              None        None            NaN    150    150         True
# 3              None        None           67.0    150     42         True
# 4              None        None            NaN    150    150         True
# ..              ...         ...            ...    ...    ...          ...
# 127            None        None            NaN    150    150         True
# 128            None        None            NaN    150    150         True
# 129            None        None           69.0    150     44         True
# 130            None        None            NaN    150    150         True
# 131            None        None            NaN    150    150         True
#
#               bead_tag  varietal_tag                        read_tag  status
# 0    CTGTTAGTTCCCACTTC  ACTTCGCTAGGC  CTGTTAGTTCCCACTTC_ACTTCGCTAGGC      ok
# 1    CTAAGAATTTACCGTGA  GTTTTAGGGCAG  CTAAGAATTTACCGTGA_GTTTTAGGGCAG      ok
# 2    TCTGGAATACCGTGTAA  AAGTACCTCGCG  TCTGGAATACCGTGTAA_AAGTACCTCGCG      ok
# 3    GCTACTGAAGCGGGTCA  CGGGTTATTGAA  GCTACTGAAGCGGGTCA_CGGGTTATTGAA      ok
# 4    TGATGGATTCAGATTCC  TGTACAATGCAC  TGATGGATTCAGATTCC_TGTACAATGCAC      ok
# ..                 ...           ...                             ...     ...
# 127  CTCATATTGGCCACAGC  TTTTATCTGAGC  CTCATATTGGCCACAGC_TTTTATCTGAGC      ok
# 128  TCAGATAAAGATGATAC  AGTAAACCCGGC  TCAGATAAAGATGATAC_AGTAAACCCGGC      ok
# 129  GATTTGTGGTGCGATGT  GTTTCATGGGGG  GATTTGTGGTGCGATGT_GTTTCATGGGGG      ok
# 130  TCTTTTGTTCCCACAGC  TCGTATTGGGCG  TCTTTTGTTCCCACAGC_TCGTATTGGGCG      ok
# 131  GATGGAATCGAGTCTTA  TACAAATACGAG  GATGGAATCGAGTCTTA_TACAAATACGAG      ok
#
# [132 rows x 24 columns]

# %%
#df_good[ df_good['read_id'] == "A00296:241:HMWTTDRXX:1:1101:27145:6073" ].iloc[0]
df_bad[ df_bad['read_id'] == "A00296:241:HMWTTDRXX:1:1101:27145:6073" ].iloc[0]
# Out:
# read_id        A00296:241:HMWTTDRXX:1:1101:27145:6073
# status                                           fail
# failed_step                           check_read_lens
# message                         Test operation failed
# Name: 108, dtype: object
